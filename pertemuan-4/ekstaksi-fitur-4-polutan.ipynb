# %% [markdown]
# # Ekstraksi 68 Fitur Runtun Waktu 4 Polutan (CH4, CO, NO2, SO2) Menggunakan Pustaka TSFEL
#
# **Dataset Input**: `data/csv/pertemuan-4-csv/polutan_4_final_clean.csv` (365 Hari Lengkap, 0 Missing Values, Bebas Pencilan)
# **Tujuan**: Mengekstrak karakteristik representatif sinyal runtun waktu (*time-series feature extraction*) untuk 4 polutan udara (`CH4`, `CO`, `NO2`, `SO2`) di Kabupaten Bangkalan menggunakan pustaka **TSFEL (*Time Series Feature Extraction Library*)**.
#
# Seluruh 4 domain keilmuan sinyal diekstrak secara komprehensif:
# 1. **Domain Statistik (*Statistical*)**: Parameter pemusatan, penyebaran, bentuk distribusi, dan probabilitas kumulatif (22 fitur).
# 2. **Domain Temporal (*Temporal*)**: Dinamika waktu, autokorelasi, lintasan sinyal, dan turning points (15 fitur).
# 3. **Domain Spektral (*Spectral*)**: Transformasi Fourier, analisis energi pita frekuensi, dan spektrogram (27 fitur).
# 4. **Domain Fraktal (*Fractal*)**: Kompleksitas skala, eksponen ketergantungan jarak jauh (DFA & Hurst), dan dimensi Higuchi/Petrosian (4 fitur).
#
# Seluruh fitur rentang nilai (*array*) diagregasikan menggunakan rata-rata (*mean*) sehingga menghasilkan format konsisten **1 Fitur = 1 Nilai Jelas** dalam bentuk matriks terstandarisasi 4 baris × 69 kolom (`fitur_68_4_polutan.csv`).

# %% [markdown]
# ## Daftar 68 Fitur TSFEL Terstandarisasi (1 Fitur = 1 Nilai Jelas)
#
# | No | Kode Fitur | Nama Fungsi TSFEL | Domain | Tipe Dimensi | Standardisasi |
# | :---: | :--- | :--- | :---: | :---: | :--- |
# | 1 | `f1_abs_energy` | `abs_energy(signal)` | Statistical | Skalar (1 Nilai) | Nilai skalar eksak |
# | 2 | `f2_auc` | `auc(signal)` | Temporal | Skalar (1 Nilai) | Nilai skalar eksak |
# | 3 | `f3_autocorr` | `autocorr(signal)` | Temporal | Skalar (1 Nilai) | Nilai skalar eksak |
# | 4 | `f4_average_power` | `average_power(signal)` | Statistical | Skalar (1 Nilai) | Nilai skalar eksak |
# | 5 | `f5_calc_centroid` | `calc_centroid(signal)` | Temporal | Skalar (1 Nilai) | Nilai skalar eksak |
# | 6 | `f6_calc_max` | `calc_max(signal)` | Statistical | Skalar (1 Nilai) | Nilai skalar eksak |
# | 7 | `f7_calc_mean` | `calc_mean(signal)` | Statistical | Skalar (1 Nilai) | Nilai skalar eksak |
# | 8 | `f8_calc_median` | `calc_median(signal)` | Statistical | Skalar (1 Nilai) | Nilai skalar eksak |
# | 9 | `f9_calc_min` | `calc_min(signal)` | Statistical | Skalar (1 Nilai) | Nilai skalar eksak |
# | 10 | `f10_calc_std` | `calc_std(signal)` | Statistical | Skalar (1 Nilai) | Nilai skalar eksak |
# | 11 | `f11_calc_var` | `calc_var(signal)` | Statistical | Skalar (1 Nilai) | Nilai skalar eksak |
# | 12 | `f12_dfa` | `dfa(signal)` | Fractal | Skalar (1 Nilai) | Nilai skalar eksak |
# | 13 | `f13_distance` | `distance(signal)` | Temporal | Skalar (1 Nilai) | Nilai skalar eksak |
# | 14 | `f14_ecdf` | `ecdf(signal)` | Statistical | Array (10 Nilai) | **Rerata Mean 10 Nilai** |
# | 15 | `f15_ecdf_percentile` | `ecdf_percentile(signal)` | Statistical | Array (2 Nilai) | **Rerata Mean 2 Nilai** |
# | 16 | `f16_ecdf_percentile_count` | `ecdf_percentile_count(signal)` | Statistical | Array (2 Nilai) | **Rerata Mean 2 Nilai** |
# | 17 | `f17_ecdf_slope` | `ecdf_slope(signal)` | Statistical | Skalar (1 Nilai) | Nilai skalar eksak |
# | 18 | `f18_entropy` | `entropy(signal)` | Statistical | Skalar (1 Nilai) | Nilai skalar eksak |
# | 19 | `f19_fundamental_frequency` | `fundamental_frequency(signal)` | Spectral | Skalar (1 Nilai) | Nilai skalar eksak |
# | 20 | `f20_higuchi_fractal_dimension` | `higuchi_fractal_dimension(signal)` | Fractal | Skalar (1 Nilai) | Nilai skalar eksak |
# | 21 | `f21_hist_mode` | `hist_mode(signal)` | Statistical | Skalar (1 Nilai) | Nilai skalar eksak |
# | 22 | `f22_human_range_energy` | `human_range_energy(signal)` | Spectral | Skalar (1 Nilai) | Nilai skalar eksak |
# | 23 | `f23_hurst_exponent` | `hurst_exponent(signal)` | Fractal | Skalar (1 Nilai) | Nilai skalar eksak |
# | 24 | `f24_interq_range` | `interq_range(signal)` | Statistical | Skalar (1 Nilai) | Nilai skalar eksak |
# | 25 | `f25_kurtosis` | `kurtosis(signal)` | Statistical | Skalar (1 Nilai) | Nilai skalar eksak |
# | 26 | `f26_lempel_ziv` | `lempel_ziv(signal)` | Temporal | Skalar (1 Nilai) | Nilai skalar eksak |
# | 27 | `f27_lpcc` | `lpcc(signal)` | Spectral | Array (12 Nilai) | **Rerata Mean 12 Nilai** |
# | 28 | `f28_max_frequency` | `max_frequency(signal)` | Spectral | Skalar (1 Nilai) | Nilai skalar eksak |
# | 29 | `f29_max_power_spectrum` | `max_power_spectrum(signal)` | Spectral | Skalar (1 Nilai) | Nilai skalar eksak |
# | 30 | `f30_maximum_fractal_length` | `maximum_fractal_length(signal)` | Fractal | Skalar (1 Nilai) | Nilai skalar eksak |
# | 31 | `f31_mean_abs_deviation` | `mean_abs_deviation(signal)` | Statistical | Skalar (1 Nilai) | Nilai skalar eksak |
# | 32 | `f32_mean_abs_diff` | `mean_abs_diff(signal)` | Temporal | Skalar (1 Nilai) | Nilai skalar eksak |
# | 33 | `f33_mean_diff` | `mean_diff(signal)` | Temporal | Skalar (1 Nilai) | Nilai skalar eksak |
# | 34 | `f34_median_abs_deviation` | `median_abs_deviation(signal)` | Statistical | Skalar (1 Nilai) | Nilai skalar eksak |
# | 35 | `f35_median_abs_diff` | `median_abs_diff(signal)` | Temporal | Skalar (1 Nilai) | Nilai skalar eksak |
# | 36 | `f36_median_diff` | `median_diff(signal)` | Temporal | Skalar (1 Nilai) | Nilai skalar eksak |
# | 37 | `f37_median_frequency` | `median_frequency(signal)` | Spectral | Skalar (1 Nilai) | Nilai skalar eksak |
# | 38 | `f38_mfcc` | `mfcc(signal)` | Spectral | Array (12 Nilai) | **Rerata Mean 12 Nilai** |
# | 39 | `f39_mse` | `mse(signal)` | Fractal | Skalar (1 Nilai) | Nilai skalar eksak |
# | 40 | `f40_negative_turning` | `negative_turning(signal)` | Temporal | Skalar (1 Nilai) | Nilai skalar eksak |
# | 41 | `f41_neighbourhood_peaks` | `neighbourhood_peaks(signal)` | Temporal | Skalar (1 Nilai) | Nilai skalar eksak |
# | 42 | `f42_petrosian_fractal_dimension` | `petrosian_fractal_dimension(signal)` | Fractal | Skalar (1 Nilai) | Nilai skalar eksak |
# | 43 | `f43_pk_pk_distance` | `pk_pk_distance(signal)` | Statistical | Skalar (1 Nilai) | Nilai skalar eksak |
# | 44 | `f44_positive_turning` | `positive_turning(signal)` | Temporal | Skalar (1 Nilai) | Nilai skalar eksak |
# | 45 | `f45_power_bandwidth` | `power_bandwidth(signal)` | Spectral | Skalar (1 Nilai) | Nilai skalar eksak |
# | 46 | `f46_rms` | `rms(signal)` | Statistical | Skalar (1 Nilai) | Nilai skalar eksak |
# | 47 | `f47_skewness` | `skewness(signal)` | Statistical | Skalar (1 Nilai) | Nilai skalar eksak |
# | 48 | `f48_slope` | `slope(signal)` | Temporal | Skalar (1 Nilai) | Nilai skalar eksak |
# | 49 | `f49_spectral_centroid` | `spectral_centroid(signal)` | Spectral | Skalar (1 Nilai) | Nilai skalar eksak |
# | 50 | `f50_spectral_decrease` | `spectral_decrease(signal)` | Spectral | Skalar (1 Nilai) | Nilai skalar eksak |
# | 51 | `f51_spectral_distance` | `spectral_distance(signal)` | Spectral | Skalar (1 Nilai) | Nilai skalar eksak |
# | 52 | `f52_spectral_entropy` | `spectral_entropy(signal)` | Spectral | Skalar (1 Nilai) | Nilai skalar eksak |
# | 53 | `f53_spectral_kurtosis` | `spectral_kurtosis(signal)` | Spectral | Skalar (1 Nilai) | Nilai skalar eksak |
# | 54 | `f54_spectral_positive_turning` | `spectral_positive_turning(signal)` | Spectral | Skalar (1 Nilai) | Nilai skalar eksak |
# | 55 | `f55_spectral_roll_off` | `spectral_roll_off(signal)` | Spectral | Skalar (1 Nilai) | Nilai skalar eksak |
# | 56 | `f56_spectral_roll_on` | `spectral_roll_on(signal)` | Spectral | Skalar (1 Nilai) | Nilai skalar eksak |
# | 57 | `f57_spectral_skewness` | `spectral_skewness(signal)` | Spectral | Skalar (1 Nilai) | Nilai skalar eksak |
# | 58 | `f58_spectral_slope` | `spectral_slope(signal)` | Spectral | Skalar (1 Nilai) | Nilai skalar eksak |
# | 59 | `f59_spectral_spread` | `spectral_spread(signal)` | Spectral | Skalar (1 Nilai) | Nilai skalar eksak |
# | 60 | `f60_spectral_variation` | `spectral_variation(signal)` | Spectral | Skalar (1 Nilai) | Nilai skalar eksak |
# | 61 | `f61_spectrogram_mean_coeff` | `spectrogram_mean_coeff(signal)` | Spectral | Array (32 Nilai) | **Rerata Mean 32 Nilai** |
# | 62 | `f62_sum_abs_diff` | `sum_abs_diff(signal)` | Temporal | Skalar (1 Nilai) | Nilai skalar eksak |
# | 63 | `f63_wavelet_abs_mean` | `wavelet_abs_mean(signal)` | Spectral | Array (9 Nilai) | **Rerata Mean 9 Nilai** |
# | 64 | `f64_wavelet_energy` | `wavelet_energy(signal)` | Spectral | Array (9 Nilai) | **Rerata Mean 9 Nilai** |
# | 65 | `f65_wavelet_entropy` | `wavelet_entropy(signal)` | Spectral | Skalar (1 Nilai) | Nilai skalar eksak |
# | 66 | `f66_wavelet_std` | `wavelet_std(signal)` | Spectral | Array (9 Nilai) | **Rerata Mean 9 Nilai** |
# | 67 | `f67_wavelet_var` | `wavelet_var(signal)` | Spectral | Array (9 Nilai) | **Rerata Mean 9 Nilai** |
# | 68 | `f68_zero_cross` | `zero_cross(signal)` | Temporal | Skalar (1 Nilai) | Nilai skalar eksak |

# %%
import os
import re
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tsfel

warnings.filterwarnings('ignore')

# 1. Definisi list 68 fitur TSFEL terstandarisasi (f1 s.d. f68)
fitur_68_list = [
    'f1_abs_energy', 'f2_auc', 'f3_autocorr', 'f4_average_power', 'f5_calc_centroid',
    'f6_calc_max', 'f7_calc_mean', 'f8_calc_median', 'f9_calc_min', 'f10_calc_std',
    'f11_calc_var', 'f12_dfa', 'f13_distance', 'f14_ecdf', 'f15_ecdf_percentile',
    'f16_ecdf_percentile_count', 'f17_ecdf_slope', 'f18_entropy', 'f19_fundamental_frequency',
    'f20_higuchi_fractal_dimension', 'f21_hist_mode', 'f22_human_range_energy', 'f23_hurst_exponent',
    'f24_interq_range', 'f25_kurtosis', 'f26_lempel_ziv', 'f27_lpcc', 'f28_max_frequency',
    'f29_max_power_spectrum', 'f30_maximum_fractal_length', 'f31_mean_abs_deviation',
    'f32_mean_abs_diff', 'f33_mean_diff', 'f34_median_abs_deviation', 'f35_median_abs_diff',
    'f36_median_diff', 'f37_median_frequency', 'f38_mfcc', 'f39_mse', 'f40_negative_turning',
    'f41_neighbourhood_peaks', 'f42_petrosian_fractal_dimension', 'f43_pk_pk_distance',
    'f44_positive_turning', 'f45_power_bandwidth', 'f46_rms', 'f47_skewness', 'f48_slope',
    'f49_spectral_centroid', 'f50_spectral_decrease', 'f51_spectral_distance', 'f52_spectral_entropy',
    'f53_spectral_kurtosis', 'f54_spectral_positive_turning', 'f55_spectral_roll_off',
    'f56_spectral_roll_on', 'f57_spectral_skewness', 'f58_spectral_slope', 'f59_spectral_spread',
    'f60_spectral_variation', 'f61_spectrogram_mean_coeff', 'f62_sum_abs_diff', 'f63_wavelet_abs_mean',
    'f64_wavelet_energy', 'f65_wavelet_entropy', 'f66_wavelet_std', 'f67_wavelet_var', 'f68_zero_cross'
]

pollutants = ['CH4', 'CO', 'NO2', 'SO2']

print(f"Total fitur dalam katalog terstandarisasi : {len(fitur_68_list)} fitur.")
print(f"Fitur pertama  : {fitur_68_list[0]}")
print(f"Fitur terakhir : {fitur_68_list[-1]}")
print(f"Target polutan : {pollutants}")
# Out:
# Total fitur dalam katalog terstandarisasi : 68 fitur.
# Fitur pertama  : f1_abs_energy
# Fitur terakhir : f68_zero_cross
# Target polutan : ['CH4', 'CO', 'NO2', 'SO2']

# %% [markdown]
# ## 1. Memuat Dataset Bersih 4 Polutan (365 Hari Lengkap)
#
# Dataset dimuat dari berkas `data/csv/pertemuan-4-csv/polutan_4_final_clean.csv` yang merupakan luaran dari tahapan imputasi missing value (`tambal-missing-4-polutan.ipynb`).

# %%
# Menentukan path file input
csv_folder = "../data/csv/pertemuan-4-csv"
if not os.path.exists(csv_folder):
    csv_folder = "data/csv/pertemuan-4-csv"

clean_data_path = os.path.join(csv_folder, "polutan_4_final_clean.csv")
df = pd.read_csv(clean_data_path)
df['tanggal'] = pd.to_datetime(df['tanggal'])

print("=== INFORMASI DATASET 4 POLUTAN (BERSIH SEMPURNA) ===")
print(f"Lokasi berkas       : {clean_data_path}")
print(f"Jumlah observasi    : {len(df)} baris (365 hari lengkap)")
print(f"Rentang waktu       : {df['tanggal'].min().strftime('%Y-%m-%d')} s/d {df['tanggal'].max().strftime('%Y-%m-%d')}")
print(f"Total Missing Values: {df.isna().sum().sum()} (0 NaN)")

profil_pol = []
for p in pollutants:
    profil_pol.append({
        'Polutan': p,
        'Jumlah Baris': len(df),
        'Missing Values': df[p].isna().sum(),
        'Nilai Min': f"{df[p].min():.6e}",
        'Rata-rata (μ)': f"{df[p].mean():.6e}",
        'Nilai Max': f"{df[p].max():.6e}",
        'Std Dev (σ)': f"{df[p].std():.6e}"
    })

display(pd.DataFrame(profil_pol))
print("\n--- 5 Baris Pertama Dataset ---")
display(df.head())
# Out:
# === INFORMASI DATASET 4 POLUTAN (BERSIH SEMPURNA) ===
# Lokasi berkas       : ../data/csv/pertemuan-4-csv\polutan_4_final_clean.csv
# Jumlah observasi    : 365 baris (365 hari lengkap)
# Rentang waktu       : 2025-08-24 s/d 2026-08-23
# Total Missing Values: 0 (0 NaN)
#   Polutan  Jumlah Baris  Missing Values      Nilai Min Rata-rata (μ)  \
# 0     CH4           365               0   1.841516e+03  1.880449e+03
# 1      CO           365               0   2.048735e-02  2.858408e-02
# 2     NO2           365               0   5.230000e-06  3.359174e-05
# 3     SO2           365               0  -4.784350e-04  5.495878e-05
#
#       Nilai Max   Std Dev (σ)
# 0  1.916853e+03  1.041489e+01
# 1  3.613363e-02  2.598121e-03
# 2  6.860000e-05  1.319949e-05
# 3  5.539490e-04  1.696823e-04
# --- 5 Baris Pertama Dataset ---
#      tanggal          CH4        CO       NO2       SO2
# 0 2025-08-24  1850.206787  0.032369  0.000030  0.000544
# 1 2025-08-25  1867.289429  0.029644  0.000040  0.000182
# ...

# %%
# Visualisasi deret waktu bersih untuk 4 polutan sepanjang 365 hari
fig, axes = plt.subplots(4, 1, figsize=(16, 14), sharex=True)
colors_map = {'CH4': '#1f77b4', 'CO': '#ff7f0e', 'NO2': '#2ca02c', 'SO2': '#9467bd'}

for i, p in enumerate(pollutants):
    ax = axes[i]
    ax.plot(df['tanggal'], df[p], color=colors_map[p], linewidth=1.5, label=f'Konsentrasi {p} Bersih')
    ax.axhline(df[p].mean(), color='red', linestyle='--', linewidth=1.2, label=f'Rata-rata (μ = {df[p].mean():.2e})')
    ax.fill_between(df['tanggal'], df[p].min(), df[p].max(), color=colors_map[p], alpha=0.08)
    
    ax.set_title(f'Runtun Waktu Konsentrasi {p} - Kabupaten Bangkalan (365 Hari Lengkap)', fontsize=11, fontweight='bold')
    ax.set_ylabel(f'Konsentrasi {p}', fontsize=10)
    ax.grid(True, linestyle=':', alpha=0.6)
    ax.legend(loc='upper right', framealpha=0.9, fontsize=9)

axes[-1].set_xlabel('Tanggal Observasi (2025 - 2026)', fontsize=11)
plt.suptitle('Dinamika Runtun Waktu Konsentrasi 4 Polutan Udara Bersih Sempurna (365 Hari)', fontsize=13, fontweight='bold', y=0.995)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Konfigurasi Seluruh Fitur TSFEL (4 Domain: 68 Fitur)
#
# Mengambil konfigurasi seluruh domain bawaan dari pustaka TSFEL (`tsfel.get_features_by_domain()`) dan memastikan seluruh fungsi fitur diaktifkan (`use = 'yes'`).

# %%
# Mengambil konfigurasi seluruh domain (Statistical, Temporal, Spectral, Fractal)
cfg = tsfel.get_features_by_domain()

# Mengaktifkan seluruh fungsi fitur yang ada tanpa terkecuali
total_fitur_bawaan = 0
for domain, features_dict in cfg.items():
    for feat_name in features_dict:
        cfg[domain][feat_name]['use'] = 'yes'
    total_fitur_bawaan += len(features_dict)

print("=== KONFIGURASI DOMAIN FITUR TSFEL AKTIF ===")
print(f"Total fungsi bawaan aktif : {total_fitur_bawaan} fungsi fitur")
for domain, features_dict in cfg.items():
    print(f"- Domain {domain.capitalize():12}: {len(features_dict)} fungsi fitur")
print("- Fitur tambahan ecdf_slope : 1 fungsi fitur")
print("-> TOTAL KESELURUHAN        : 68 FUNGSI FITUR LENGKAP")
# Out:
# === KONFIGURASI DOMAIN FITUR TSFEL AKTIF ===
# Total fungsi bawaan aktif : 67 fungsi fitur
# - Domain Spectral    : 26 fungsi fitur
# - Domain Statistical : 20 fungsi fitur
# - Domain Temporal    : 15 fungsi fitur
# - Domain Fractal     : 6 fungsi fitur
# - Fitur tambahan ecdf_slope : 1 fungsi fitur
# -> TOTAL KESELURUHAN        : 68 FUNGSI FITUR LENGKAP

# %% [markdown]
# ## 3. Eksekusi Ekstraksi Fitur Runtun Waktu Menggunakan TSFEL untuk 4 Polutan
#
# Ekstraksi dijalankan secara berurutan untuk masing-masing polutan (`CH4`, `CO`, `NO2`, `SO2`) menggunakan `tsfel.time_series_features_extractor()`, kemudian ditambahkan perhitungan `ecdf_slope`.
#
# Untuk memenuhi standardisasi **1 Fitur = 1 Nilai Jelas**, seluruh 10 fungsi fitur yang menghasilkan koefisien multi-dimensi (*array*) diagregasikan menggunakan rata-rata (*mean*) dari seluruh koefisiennya.

# %%
# Memuat referensi katalog 68 fitur untuk pemetaan nama dan tipe dimensi
tabel_ref_path = "../data/csv/pertemuan-3-csv/fitur_68_tsfel_co_bangkalan_tabel.csv"
if not os.path.exists(tabel_ref_path):
    tabel_ref_path = "data/csv/pertemuan-3-csv/fitur_68_tsfel_co_bangkalan_tabel.csv"

df_tabel_ref = pd.read_csv(tabel_ref_path)

def extract_standard_68(df_input, pol_name):
    print(f"Mengekstrak fitur untuk polutan: {pol_name} ...")
    series = df_input[pol_name]
    
    # 1. Ekstraksi mentah TSFEL
    raw = tsfel.time_series_features_extractor(cfg, series.to_frame(pol_name), verbose=0)
    raw[f'{pol_name}_ECDF Slope'] = tsfel.ecdf_slope(series)
    
    # 2. Pemetaan terstandarisasi ke 68 fitur skalar tunggal
    vals = {}
    for idx, row in df_tabel_ref.iterrows():
        f_code = row['Kode Fitur']
        f_name = row['Nama Fitur']
        fn_tsfel = row['Nama Fungsi TSFEL'].split('(')[0].strip()
        
        if f_code == 'f14_ecdf':
            matched = [c for c in raw.columns if re.match(rf'^{pol_name}_ECDF_\d+$', c)]
        elif f_code == 'f15_ecdf_percentile':
            matched = [c for c in raw.columns if re.match(rf'^{pol_name}_ECDF Percentile_\d+$', c)]
        elif f_code == 'f16_ecdf_percentile_count':
            matched = [c for c in raw.columns if re.match(rf'^{pol_name}_ECDF Percentile Count_\d+$', c)]
        elif f_code == 'f17_ecdf_slope':
            matched = [f'{pol_name}_ECDF Slope']
        else:
            matched = [c for c in raw.columns if c.replace(f'{pol_name}_', '').lower() == f_name.lower()]
            if not matched:
                matched = [c for c in raw.columns if c.replace(f'{pol_name}_', '').lower().startswith(f_name.lower())]
            if not matched:
                matched = [c for c in raw.columns if fn_tsfel.lower() in c.lower()]
                
        if len(matched) == 1:
            vals[f_code] = raw[matched[0]].iloc[0]
        elif len(matched) > 1:
            vals[f_code] = raw[matched].iloc[0].mean()
        else:
            vals[f_code] = np.nan
            
    df_single = pd.DataFrame([vals], columns=fitur_68_list)
    df_single.insert(0, 'Polutan', pol_name)
    return df_single, raw

# Eksekusi ekstraksi untuk ke-4 polutan
dict_68_dfs = {}
raw_dfs = []

for pol in pollutants:
    df_68_pol, raw_pol = extract_standard_68(df, pol)
    dict_68_dfs[pol] = df_68_pol
    raw_dfs.append(raw_pol)

# Gabungkan matriks mentah
df_raw_combined = pd.concat(raw_dfs, axis=1)
raw_path = os.path.join(csv_folder, "fitur_tsfel_4_polutan_raw.csv")
df_raw_combined.to_csv(raw_path, index=False)

print("\n" + "=" * 80)
print("EKSTRAKSI FITUR TSFEL 4 POLUTAN SELESAI")
print(f"✓ Matriks mentah TSFEL berhasil disimpan di: {raw_path}")
print(f"  Dimensi mentah: {df_raw_combined.shape}")
print("=" * 80)
# Out:
# Mengekstrak fitur untuk polutan: CH4 ...
# Mengekstrak fitur untuk polutan: CO ...
# Mengekstrak fitur untuk polutan: NO2 ...
# Mengekstrak fitur untuk polutan: SO2 ...
# ...
# EKSTRAKSI FITUR TSFEL 4 POLUTAN SELESAI
# ✓ Matriks mentah TSFEL berhasil disimpan di: ../data/csv/pertemuan-4-csv\fitur_tsfel_4_polutan_raw.csv
#   Dimensi mentah: (1, 656)
# ...

# %% [markdown]
# ## 4. Penyusunan Matriks Fitur Terstandarisasi (4 Baris × 69 Kolom)
#
# Seluruh 68 nilai fitur dari ke-4 polutan digabungkan ke format horizontal **4 baris × 69 kolom fitur** (Kolom identitas `Polutan` + `f1_abs_energy` s/d `f68_zero_cross`). Berkas ini disimpan sebagai `fitur_68_4_polutan.csv`, serta disediakan berkas individual per-polutan (`fitur_68_{pol}_1baris.csv`).

# %%
# 1. Menggabungkan DataFrame 4 Polutan ke format Horizontal (4 baris x 69 kolom)
df_68_horizontal = pd.concat([dict_68_dfs[p] for p in pollutants], ignore_index=True)

# Simpan matriks gabungan 4 polutan
horizontal_path = os.path.join(csv_folder, "fitur_68_4_polutan.csv")
df_68_horizontal.to_csv(horizontal_path, index=False)
print(f"✓ Matriks 4 Polutan terstandarisasi disimpan di:\n  {horizontal_path}")

# 2. Simpan juga berkas individual per-polutan untuk fleksibilitas integrasi
for pol in pollutants:
    p_path = os.path.join(csv_folder, f"fitur_68_{pol.lower()}_1baris.csv")
    dict_68_dfs[pol].to_csv(p_path, index=False)
    print(f"✓ Berkas individual {pol:4} disimpan di: {p_path}")

print("\n=== MATRIKS FITUR HORIZONTAL 4 POLUTAN (4 BARIS x 69 KOLOM) ===")
print(f"Dimensi matriks: {df_68_horizontal.shape}")
print(f"Missing values : {df_68_horizontal.isna().sum().sum()} (0 NaN)")

pd.set_option('display.max_columns', 15)
display(df_68_horizontal)
# Out:
# ✓ Matriks 4 Polutan terstandarisasi disimpan di:
#   ../data/csv/pertemuan-4-csv\fitur_68_4_polutan.csv
# ✓ Berkas individual CH4  disimpan di: ../data/csv/pertemuan-4-csv\fitur_68_ch4_1baris.csv
# ✓ Berkas individual CO   disimpan di: ../data/csv/pertemuan-4-csv\fitur_68_co_1baris.csv
# ✓ Berkas individual NO2  disimpan di: ../data/csv/pertemuan-4-csv\fitur_68_no2_1baris.csv
# ✓ Berkas individual SO2  disimpan di: ../data/csv/pertemuan-4-csv\fitur_68_so2_1baris.csv
#
# === MATRIKS FITUR HORIZONTAL 4 POLUTAN (4 BARIS x 69 KOLOM) ===
# Dimensi matriks: (4, 69)
# Missing values : 0 (0 NaN)
#   Polutan  f1_abs_energy       f2_auc  f3_autocorr  f4_average_power  \
# 0     CH4   1.290712e+09  6844.832066         17.0      3.545911e+08
# 1      CO   3.006801e-01     0.104004          2.0      8.260443e-02
# 2     NO2   4.752863e-07     0.000122          7.0      1.305732e-07
# 3     SO2   1.158279e-05     0.000423          2.0      3.182084e-06
#
# ...

# %% [markdown]
# ## 5. Visualisasi Profil Komparatif Karakteristik Fitur 4 Polutan
#
# Membandingkan karakteristik sinyal antar 4 polutan berdasarkan fitur-fitur kunci yang dinormalisasi (Z-score normalisasi atau Min-Max) dari domain statistik, temporal, dan fraktal.

# %%
# 1. Bar Chart Komparasi Fitur-Fitur Kunci Antar 4 Polutan
fig, axes = plt.subplots(2, 3, figsize=(16, 9))
axes = axes.flatten()

key_features = [
    ('f7_calc_mean', 'Rata-rata Konsentrasi (Mean)'),
    ('f10_calc_std', 'Variabilitas Harian (Std Dev)'),
    ('f46_rms', 'Root Mean Square (RMS)'),
    ('f18_entropy', 'Shannon Entropy (Kompleksitas)'),
    ('f23_hurst_exponent', 'Hurst Exponent (Memori/Tren)'),
    ('f13_distance', 'Total Lintasan Sinyal (Distance)')
]

for i, (f_code, title) in enumerate(key_features):
    ax = axes[i]
    vals = df_68_horizontal[f_code].values
    bars = ax.bar(pollutants, vals, color=[colors_map[p] for p in pollutants], edgecolor='black', alpha=0.85)
    ax.set_title(f'{title}\n({f_code})', fontsize=11, fontweight='bold')
    ax.grid(axis='y', linestyle='--', alpha=0.4)
    
    # Format nilai teks di atas bar
    for bar in bars:
        yval = bar.get_height()
        ax.text(bar.get_x() + bar.get_width()/2.0, yval + 0.01 * yval, f"{yval:.2e}", ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.suptitle('Komparasi Nilai Fitur Kunci Runtun Waktu Antar 4 Polutan Udara', fontsize=13, fontweight='bold', y=1.01)
plt.tight_layout()
plt.show()

# 2. Radar Profile Chart Karakteristik 4 Polutan
radar_feats = ['f7_calc_mean', 'f6_calc_max', 'f10_calc_std', 'f23_hurst_exponent', 'f46_rms', 'f18_entropy', 'f47_skewness', 'f25_kurtosis']
radar_names = ['Mean (f7)', 'Max (f6)', 'Std Dev (f10)', 'Hurst (f23)', 'RMS (f46)', 'Entropy (f18)', 'Skewness (f47)', 'Kurtosis (f25)']

# Normalisasi Min-Max per kolom fitur agar dapat dibandingkan di radar [0.15, 1.0]
df_norm = df_68_horizontal[radar_feats].copy()
for col in radar_feats:
    c_min = df_norm[col].min()
    c_max = df_norm[col].max()
    if c_max > c_min:
        df_norm[col] = (df_norm[col] - c_min) / (c_max - c_min) * 0.8 + 0.2
    else:
        df_norm[col] = 0.5

angles = np.linspace(0, 2 * np.pi, len(radar_names), endpoint=False).tolist()
angles_cycle = np.concatenate((angles, [angles[0]]))

fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))
for idx, pol in enumerate(pollutants):
    v = df_norm.iloc[idx].values
    v_cycle = np.concatenate((v, [v[0]]))
    ax.plot(angles_cycle, v_cycle, label=pol, color=colors_map[pol], linewidth=2.2)
    ax.fill(angles_cycle, v_cycle, color=colors_map[pol], alpha=0.15)

ax.set_theta_offset(np.pi / 2)
ax.set_theta_direction(-1)
ax.set_thetagrids(np.degrees(angles), radar_names, fontsize=9, fontweight='bold')
ax.set_ylim(0, 1.1)
ax.set_title('Diagram Radar Profil Multidimensi 4 Polutan Udara Bangkalan', fontsize=13, fontweight='bold', pad=22)
ax.legend(loc='upper right', bbox_to_anchor=(1.25, 1.1), framealpha=0.9, fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Kesimpulan & Kesiapan Integrasi Tugas Pertemuan 4
#
# Proses ekstraksi 68 fitur runtun waktu untuk 4 polutan udara di Kabupaten Bangkalan telah selesai dengan capaian:
# 1. **Daftar Lengkap 68 Fitur**: Seluruh 68 fitur TSFEL berhasil diekstrak untuk ke-4 polutan (`CH4`, `CO`, `NO2`, `SO2`) dengan kode standar `f1_abs_energy` s/d `f68_zero_cross`.
# 2. **Standardisasi 1 Nilai**: 10 fitur rentang nilai (*array*) berhasil diagregasikan menggunakan nilai rata-rata (*mean*) sehingga menghasilkan format seragam **1 Fitur = 1 Nilai Numerik**.
# 3. **Format Horizontal Matriks**: Data telah siap dalam format matriks 4 baris × 69 kolom (`fitur_68_4_polutan.csv`) yang 100% siap digabungkan dengan dataset rekan mahasiswa untuk **Tugas Pertemuan 4** (*merging all student data*).
#
# ### Berkas Luaran yang Dihasilkan pada Folder `data/csv/pertemuan-4-csv/`:
# - `polutan_4_clean.csv` (Dataset bebas outlier 365 hari, outlier di-NaN-kan)
# - `polutan_4_outliers_list.csv` (Katalog 23 data outlier terurut)
# - `polutan_4_final_clean.csv` (Dataset bersih sempurna 365 hari lengkap hasil interpolasi linear)
# - `fitur_68_4_polutan.csv` (Matriks horizontal 4 baris × 69 kolom: Polutan + 68 kode fitur)
# - `fitur_68_ch4_1baris.csv`, `fitur_68_co_1baris.csv`, `fitur_68_no2_1baris.csv`, `fitur_68_so2_1baris.csv` (Berkas individual 1 baris per polutan)
# - `fitur_tsfel_4_polutan_raw.csv` (Matriks mentah ekstraksi TSFEL)
